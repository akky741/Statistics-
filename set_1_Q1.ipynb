# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import statsmodels.api as smf
import warnings
warnings.filterwarnings('ignore')

# %%
measure_x = pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])
name_of_company = ['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers',
      'Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways',
      'Warner-Lambert']

# %%
#data = pd.DataFrame({'company':name_of_company ,  'measure':measure_x})
data = pd.DataFrame(list(zip(measure_x,name_of_company)), columns =['Measure X', 'Name of company'])
data
# Out:
#     Measure X   Name of company
# 0       24.23     Allied Signal
# 1       25.53     Bankers Trust
# 2       25.41     General Mills
# 3       24.14    ITT Industries
# 4       29.62  J.P.Morgan & Co.
# 5       28.25   Lehman Brothers
# 6       25.81          Marriott
# 7       24.39               MCI
# 8       40.26     Merrill Lynch
# 9       32.95         Microsoft
# 10      91.36    Morgan Stanley
# 11      25.99  Sun Microsystems
# 12      39.42         Travelers
# 13      26.71        US Airways
# 14      35.00    Warner-Lambert

# %%
plt.figure(figsize=(10,5))
plt.pie(measure_x, labels = name_of_company, autopct='%1.1f%%',shadow = True,
        textprops = {'size':'medium',
                   'fontweight':'bold',
                   'color':'b'})
plt.title('Name of company with respect to Measure_X', fontsize = 20, fontweight = 'bold', color='r')
plt.show()

# %%
plt.bar(x=name_of_company, height=measure_x, edgecolor='black')
plt.title('Name of the companies with respect to Measure_X')
plt.xlabel('Name of the companies')
plt.xticks(rotation=90)
plt.ylabel('Measure X')
plt.figure(figsize=(10,5))
plt.show()

# %%
sns.boxplot(y= measure_x)
plt.show()

# %%
y= measure_x
print(y.mean())
print(y.std())
print(y.var())
# Out:
# 33.27133333333333
# 16.945400921222028
# 287.1466123809524

# %%
x=pd.Series(y)
Q1=np.quantile(y,0.25)
Q3=np.quantile(y,0.75)
IQR=Q3-Q1
Upper_bound=Q3+(1.5*IQR)
Lower_bound=Q1-(1.5*IQR)
med=np.median(y)
print("First Quantile=",Q1,"Second Quantile=",med, "Third Quantile=",Q3,"Inter Quantile Range=",IQR,"Upper Whisker=",Upper_bound,"Lower Whisker=",Lower_bound)
Outliers=x[(x<=Lower_bound) | (x>=Upper_bound)]
print("The Outlier in the boxplot:",Outliers)
# Out:
# First Quantile= 25.47 Second Quantile= 26.71 Third Quantile= 33.975 Inter Quantile Range= 8.505000000000003 Upper Whisker= 46.7325 Lower Whisker= 12.712499999999995
# The Outlier in the boxplot: 10    91.36
# dtype: float64
